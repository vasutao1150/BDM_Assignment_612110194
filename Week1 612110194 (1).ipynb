# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Title1
#
# ## Title2
#
# ### Title 3
#
# Description

# %%
2 + 3
# Out:
# 5

# %%
print ("Hello World")
# Out:
# Hello World

# %%
name = "Vasu"
print ("Hello "+name+" !")
# Out:
# Hello Vasu !

# %%
country = input("Where are you from = ")
# Out:
# Where are you from = Thailand

# %%
print ("I am from " + country)
# Out:
# I am from Thailand

# %%
age = input ("What is your age =")
# Out:
# What is your age =20

# %%
print ("I am "+age+" !!")
# Out:
# I am 20 !!

# %%
name = input ("Who is your gf ? = ")
# Out:
# Who is your gf ? = Charitaka

# %%
print ("My gf is "+name+"")
# Out:
# My gf is Charitaka

# %% [markdown]
# ## HW(EX1) : DONE!

# %%
age = input(str("How old are you? ="))
tenyear_age = int(age) + (10)
print(tenyear_age)
# Out:
# How old are you? =10
# 1010

# %% [markdown]
# # 2.Variable

# %%
age = 25
print(age)
# Out:
# 25

# %%
goal = "Being Data Scientist !!"
print(goal)
# Out:
# Being Data Scientist !!

# %%
pi = 3.14
print(pi)
# Out:
# 3.14

# %% [markdown]
#  ## HW(EX2) : DONE!

# %%
print ("The pi is equal to  %.2f" % (pi))
# Out:
# The pi is equal to  3.14

# %% [markdown]
# ## 3.Arithmetic Operations

# %%
5+2 - (4*3)
# Out:
# -5

# %%
5//2
# Out:
# 2

# %%
5/2
# Out:
# 2.5

# %%
5%2
# Out:
# 1

# %%
5**2
# Out:
# 25

# %%
7**2
# Out:
# 49

# %%
a = input("What is your A =")
b = input("What is your B =")
# Out:
# What is your A =20
# What is your B =30

# %% [markdown]
#  ## HW(EX3) Fix Runtime! : DONE!

# %%
a = input("What is your A =")
b = input("What is your B =")
c = int(a) + int(b)
print (c)
# Out:
# What is your A =20
# What is your B =30
# 50

# %% [markdown]
# # 4.Strings

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
greeting = "Hello"
name = "World"
print(greeting + name)
# Out:
# HelloWorld

# %%
msg = "Hello" + "World"
print (msg)
# Out:
# HelloWorld

# %%
"ap" in "apple"
# Out:
# True

# %%
"z" in "apple"
# Out:
# False

# %%
"a" in "Apple"
# Out:
# False

# %%
name = "Vasu"
age = 20
msg = f"Hello my name is {name} and my age is {age}"
print (msg)
# Out:
# Hello my name is Vasu and my age is 20

# %%
print("Hello my name is "+name+" and my age is "+str(age))
# Out:
# Hello my name is Vasu and my age is 20

# %%
print("Hello my name is %s and my age is %.2f" %(name,age))
# Out:
# Hello my name is Vasu and my age is 20.00

# %%
print("Hello my name is {:} and my age is {:.2f}".format(name,age))
# Out:
# Hello my name is Vasu and my age is 20.00

# %%
my_string = "Hello World"
my_string.upper()
# Out:
# 'HELLO WORLD'

# %%
my_string.lower()
# Out:
# 'hello world'

# %%
my_string.find("World")
# Out:
# 6

# %%
my_string.index("World")
# Out:
# 6

# %%
my_string.capitalize()
# Out:
# 'Hello world'

# %%
my_string.replace("World","")
# Out:
# 'Hello '

# %%
my_string.rstrip()
# Out:
# 'Hello World'

# %%
my_string[2]
# Out:
# 'l'

# %%
my_string.join("ABCD")
# Out:
# 'AHello WorldBHello WorldCHello WorldD'

# %% [markdown]
# ## HW(EX4) : DONE!

# %%
print ("['Hello','World']")
# Out:
# ['Hello','World']

# %% [markdown]
# # 5.List

# %%
L = [1,2,3,"Hello","World"]
L
# Out:
# [1, 2, 3, 'Hello', 'World']

# %%
L.append("Vasu")

# %%
print(L)
# Out:
# [1, 2, 3, 'Hello', 'World', 'Vasu']

# %%
L.remove(3)
L
# Out:
# [1, 2, 'Hello', 'World', 'Vasu']

# %%
L.pop(1)
L
# Out:
# [1, 'Hello', 'World', 'Vasu']

# %%
L = [
    [1,2,3],[4,5,6],[7,8,9]
    ]
L
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
L.reverse()
L
# Out:
# [[7, 8, 9], [4, 5, 6], [1, 2, 3]]

# %%
L.sort()
L
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %% [markdown]
# ## HW(EX5) Descending : DONE!

# %%
L.sort(reverse=True)
L
# Out:
# [[7, 8, 9], [4, 5, 6], [1, 2, 3]]

# %%
L=[]
L
# Out:
# []

# %%
L.append(1)
L.append(2)
L.append(3)
L
# Out:
# [1, 2, 3]

# %%
L = [1,2,3] + [4,5]
L
# Out:
# [1, 2, 3, 4, 5]

# %%
len(L)
# Out:
# 5

# %% [markdown]
# # 6.Dictionary

# %%
course = {
    "954340" : "Enterprise Database",
    "954471" : "Business Data Mining",
    "954472" : "Business Data Visualization"
}
print (course)
# Out:
# {'954340': 'Enterprise Database', '954471': 'Business Data Mining', '954472': 'Business Data Visualization'}

# %%
course["954471"]
# Out:
# 'Business Data Mining'

# %% [markdown]
# ### Add key

# %%
course["954499"] = "Independent Study"
course
# Out:
# {'954340': 'Enterprise Database',
#  '954471': 'Business Data Mining',
#  '954472': 'Business Data Visualization',
#  '954499': 'Independent Study'}

# %%
course.keys()
# Out:
# dict_keys(['954340', '954471', '954472', '954499'])

# %%
course.values()
# Out:
# dict_values(['Enterprise Database', 'Business Data Mining', 'Business Data Visualization', 'Independent Study'])

# %%
list(course.values())
# Out:
# ['Enterprise Database',
#  'Business Data Mining',
#  'Business Data Visualization',
#  'Independent Study']

# %%
sorted(course)
# Out:
# ['954340', '954471', '954472', '954499']

# %% [markdown]
# ## HW(EX6) Sorted by value : DONE!

# %%
sorted(course.values())
# Out:
# ['Business Data Mining',
#  'Business Data Visualization',
#  'Enterprise Database',
#  'Independent Study']

# %%
"954472" in course
# Out:
# True

# %%
"Business Data Mining" in course
# Out:
# False

# %%
course = {}
course.update({"954471":"Business Data Mining"})
course.update({"954472":"Business Data Visualization"})
course
# Out:
# {'954471': 'Business Data Mining', '954472': 'Business Data Visualization'}

# %%
len(course)
# Out:
# 2
